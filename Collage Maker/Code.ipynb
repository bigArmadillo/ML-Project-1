# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
tr = cv2.imread("top_right.jpg")

# %%
tr.shape
# Out:
# (228, 300, 3)

# %%
tr
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
tr = cv2.resize(tr,(200,200))

# %%
tr.shape
# Out:
# (200, 200, 3)

# %%
plt.imshow(tr)

# %%
tr1 = cv2.imread("top_right.jpg")
plt.imshow(tr1)

# %%
tl = cv2.imread("top_left.jpg")
tl = cv2.resize(tl,(200,200))
tl.shape
plt.imshow(tl)

# %%
tl1 = cv2.cvtColor(tl,cv2.COLOR_BGR2RGB)
plt.imshow(tl1)

# %%
br = cv2.imread("bottom_right.jpg")
br1 = cv2.cvtColor(br, cv2.COLOR_BGR2RGB)
br1 = cv2.resize(br1,(200,200))
plt.imshow(br1)

# %%
tr1 = cv2.cvtColor(tr, cv2.COLOR_BGR2RGB)
plt.imshow(tr1)

# %%
bl = cv2.imread("bottom_left.jpg")
bl1 = cv2.cvtColor(bl, cv2.COLOR_BGR2RGB)
bl1 = cv2.resize(bl1,(200,200))
plt.imshow(bl1)

# %%
cr = cv2.imread("center.jpeg")
cr1 = cv2.cvtColor(cr, cv2.COLOR_BGR2RGB)
cr1 = cv2.resize(cr1,(100,100))
plt.imshow(cr1)

# %%
type(cr)
# Out:
# numpy.ndarray

# %%
cr1.shape
# Out:
# (100, 100, 3)

# %%
one = np.hstack([tl1,tr1])

# %%
plt.imshow(one)

# %%
two = np.hstack([bl1,br1])
plt.imshow(two)

# %%
three = np.vstack([one,two])
plt.imshow(three)

# %%
tr2 = cv2.copyMakeBorder(tr1,10,10,0,10,cv2.BORDER_CONSTANT)
plt.imshow(tr2)

# %%
tl2 = cv2.copyMakeBorder(tl1,10,10,10,10,cv2.BORDER_CONSTANT)
plt.imshow(tl2)

# %%
bl2 = cv2.copyMakeBorder(bl1,0,10,10,10,cv2.BORDER_CONSTANT)
plt.imshow(bl2)

# %%
br2 = cv2.copyMakeBorder(br1,0,10,0,10,cv2.BORDER_CONSTANT)
plt.imshow(br2)

# %%
three1 = np.vstack([ np.hstack([tl2,tr2]), np.hstack([bl2,br2]) ])
plt.imshow(three1)

# %%
three1.shape
# Out:
# (430, 430, 3)

# %%
cr2 = cv2.copyMakeBorder(cr1, 10,10,10,10, cv2.BORDER_CONSTANT)
plt.imshow(cr2)

# %%
three1[ 155:275, 155:275, :  ] = cr2
plt.imshow(three1)

# %%
three1.shape
# Out:
# (430, 430, 3)

# %%
three2 = three1.reshape(-1,3)

# %%
three2.shape
# Out:
# (184900, 3)

# %%
collage = pd.DataFrame(three2)
collage.to_csv("submission.csv",header=['r','g','b'],index=False)
